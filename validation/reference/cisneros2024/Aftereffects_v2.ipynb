# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math 
import scipy.stats as stats

# %%
#95 percent CI given by the error bars of graph converted to standard deviation
def CI_95_to_SD(CI,N):
    #CI = 1.96 * SE
    #SE = CI/1.96
    #SE = SD/root(Sample Size)
    #SD = SE * root(Sample Size)
     
    SE = CI/1.96
    
    SD = SE * np.sqrt(N)
    
    return SD

def SE_to_SD(SE, N):
    return SE * np.sqrt(N)

# %%
#get cohen's d
def SMD(mean1, mean2, sd1, sd2, n1, n2):
    
    diff_means = (mean1 - mean2)
    pooled_sd = np.sqrt(((n1 - 1) * (sd1**2) + (n2 - 1) * (sd2**2))/ (n1 + n2 - 2))
    
    return diff_means / pooled_sd


def SE_SMD(n1,n2,d):
    
    return np.sqrt((n1 + n2)/(n1 * n2) + d**2 / (2 * (n1 + n2 -2)))


def get_95_CI(d, SE_coh):
    low = d - 1.96 * SE_coh
    high = d + 1.96 * SE_coh
    
    return low, high

# %%
### Vachon non-instructed (NIN) ###
Vachon_N_young_NIN = 16
Vachon_N_old_NIN = 18

# extracted from fig 4 (using webplotdigitizer)
Vachon_m_young_NIN = 15.06
Vachon_m_old_NIN = 15.71

Vachon_CI_young_NIN = 1.8
Vachon_CI_old_NIN = 3.11

Vachon_sd_young_NIN = CI_95_to_SD(Vachon_CI_young_NIN,Vachon_N_young_NIN)
Vachon_sd_old_NIN = CI_95_to_SD(Vachon_CI_old_NIN, Vachon_N_old_NIN)

vachon_SMD_NIN = -SMD(Vachon_m_young_NIN, Vachon_m_old_NIN, 
                     Vachon_sd_young_NIN,Vachon_sd_old_NIN, 
                     Vachon_N_young_NIN, Vachon_N_old_NIN)

vachon_SE_SMD_NIN = SE_SMD(Vachon_N_young_NIN, Vachon_N_old_NIN, 
                           vachon_SMD_NIN)

vachon_low_NIN, vachon_high_NIN = get_95_CI(vachon_SMD_NIN, vachon_SE_SMD_NIN)

print(vachon_SMD_NIN, vachon_low_NIN, vachon_high_NIN, vachon_SE_SMD_NIN)
# Out:
# 0.11788745980255169 -0.5561721939739324 0.7919471135790357 0.34390798662065514

# %%
### Vachon instructed (IN) ###
Vachon_N_young_IN = 21
Vachon_N_old_IN = 17

# extracted from fig 4 (using webplotdigitizer)
Vachon_m_young_IN = 13.58
Vachon_m_old_IN = 19.8

Vachon_CI_young_IN = 2.62
Vachon_CI_old_IN = 1.88

Vachon_sd_young_IN = CI_95_to_SD(Vachon_CI_young_IN,Vachon_N_young_IN)
Vachon_sd_old_IN = CI_95_to_SD(Vachon_CI_old_IN, Vachon_N_old_IN)

vachon_SMD_IN = -SMD(Vachon_m_young_IN, Vachon_m_old_IN, 
                    Vachon_sd_young_IN, Vachon_sd_old_IN,
                    Vachon_N_young_IN, Vachon_N_old_IN)

vachon_SE_SMD_IN = SE_SMD(Vachon_N_young_IN, Vachon_N_old_IN, 
                          vachon_SMD_IN)

vachon_low_IN, vachon_high_IN = get_95_CI(vachon_SMD_IN, vachon_SE_SMD_IN)

print(vachon_SMD_IN, vachon_low_IN, vachon_high_IN, vachon_SE_SMD_IN)
# Out:
# 1.179731433049911 0.4846283719043455 1.8748344941954764 0.3546444189518191

# %%
### Heuer & Hegele, 2011 ###
Heuer_2011_yng_n = 22
Heuer_2011_old_n = 18

Heuer_2011_yng_m = 13.58
Heuer_2011_old_m = 19.8

Heuer_2011_yng_se = 2.62
Heuer_2011_old_se = 1.88

Heuer_2011_yng_sd = Heuer_2011_yng_se * np.sqrt(Heuer_2011_yng_n)
Heuer_2011_old_sd = Heuer_2011_old_se * np.sqrt(Heuer_2011_old_n)

Heuer_2011_SMD = -SMD(Heuer_2011_yng_m, Heuer_2011_old_m, 
                      Heuer_2011_yng_sd, Heuer_2011_old_sd,
                      Heuer_2011_yng_n, Heuer_2011_old_n)

Heuer_2011_SE_SMD = SE_SMD(Heuer_2011_yng_n, Heuer_2011_old_n, Heuer_2011_SMD)

Heuer_2011_low, Heuer_2011_high = get_95_CI(Heuer_2011_SMD,Heuer_2011_SE_SMD)

print(Heuer_2011_SMD, Heuer_2011_SE_SMD,Heuer_2011_low, Heuer_2011_high)
#0.33033062936141955 0.1375519664516177 1.4324480335483822
# Out:
# 0.5879503584390161 0.3248978240348528 -0.04884937666929534 1.2247500935473274

# %%
# Heuer & Hegele, 2013
Heuer_2013_young_N = 38
Heuer_2013_old_N = 38

#two-way f-test on aftereffects
Heuer_2013_F = 1.4

Heuer_2013_SMD = 0.3839
Heuer_2013_SE_SMD = SE_SMD(Heuer_2013_young_N, Heuer_2013_old_N, Heuer_2013_SMD)
Heuer_2013_CI_low, Heuer_2013_CI_high = get_95_CI(Heuer_2013_SMD, Heuer_2013_SE_SMD)

print(Heuer_2013_SE_SMD, Heuer_2013_CI_low, Heuer_2013_CI_high)
#-0.594012 -0.17378800000000003
# Out:
# 0.23157587184407055 -0.06998870881437824 0.8377887088143783

# %%
### Seidler 2006 ###

## Exp 3 ; 30 Deg Rotation ##
Seidler_exp3_N_young = 10
Seidler_exp3_N_old = 10

Seidler_exp3_m_young = 16.16 
Seidler_exp3_m_old = 26.25


### TEST STATISTICS ###
#cohen's d
seidler_exp3_given_F = 11.4

ss_total = stats.halfgennorm.isf(0.05, 1, 17)
eta_squared = seidler_exp3_given_F/ss_total

seidler_exp3_SMD = np.sqrt(eta_squared/(1-eta_squared))

# #standard error on cohen's d
seidler_exp3_SE_SMD = SE_SMD(Seidler_exp3_N_young, Seidler_exp3_N_old, seidler_exp3_SMD)

# #confidence interval around cohen's d
seidler_exp3_low, seidler_exp3_high = get_95_CI(seidler_exp3_SMD, seidler_exp3_SE_SMD)

print(seidler_exp3_SMD, seidler_exp3_low, seidler_exp3_high, seidler_exp3_SE_SMD)
#1.0151698744918527 3.255630125508148 0.5715459824021161
# Out:
# 1.1516247383966967 0.1977670473815336 2.1054824294118597 0.4866620872526342

# %%
## Exp 4 ; 45 Deg Rotation ##
seidler_exp4_N_young = 10
seidler_exp4_N_old = 10

### TEST STATISTICS ###
#cohen's d
seidler_exp4_given_F = 12.5

ss_total = stats.halfgennorm.isf(0.05, 1, 16)
eta_squared = seidler_exp4_given_F/ss_total

seidler_exp4_SMD = np.sqrt(eta_squared/(1-eta_squared))

#standard error on cohen's d
seidler_exp4_SE_SMD = SE_SMD(seidler_exp4_N_young, seidler_exp4_N_old, 
                             seidler_exp4_SMD)

#confidence interval around cohen's d
seidler_exp4_low, seidler_exp4_high = get_95_CI(seidler_exp4_SMD, 
                                                seidler_exp4_SE_SMD)


print(seidler_exp4_SMD, seidler_exp4_SE_SMD, seidler_exp4_low, seidler_exp4_high)
#2.236 0.5821343869283487 1.0950166016204368 3.3769833983795636
# Out:
# 1.3872059665378784 0.5034420520995189 0.4004595444228215 2.3739523886529352

# %%
### Buch 2003 ###

Buch_young_N = 5
Buch_old_N = 5

Buch_young_m = 1.886
Buch_old_m = 2.991

Buch_yng_sme = 2.725 - Buch_young_m
Buch_old_sme = 3.415 - Buch_old_m

Buch_sd_old = Buch_old_sme * np.sqrt(Buch_young_N)
Buch_sd_young = Buch_yng_sme * np.sqrt(Buch_old_N)


### TEST STATISTICS ###

#cohen's d
buch_SMD = -SMD(Buch_young_m, Buch_old_m, 
               Buch_young_sd, Buch_old_sd,
               Buch_young_N, Buch_old_N)

#standard error on cohen's d
buch_SE_SMD = SE_SMD(Buch_young_N, Buch_old_N, 
                     buch_SMD)

#confidence interval around cohen's d
buch_low, buch_high = get_95_CI(buch_SMD, buch_SE_SMD)

print(buch_SMD, buch_SE_SMD, buch_low, buch_high)
# Out:
# 0.675678316970507 0.6546249493041845 -0.6073865836656946 1.9587432176067086

# %%
### Vandevoorde et al. 2019 ###
# Experiment E1a
vand_e1a_yng_n = 20
vand_e1a_old_n = 20

# extracted from fig 2d (using webplotdigitizer)
vand_e1a_yng_m = 10.8668
vand_e1a_old_m = 12.4148

vand_e1a_yng_se = 11.8575 - vand_e1a_yng_m
vand_e1a_old_se = 14.1795 - vand_e1a_old_m

vand_e1a_yng_sd = vand_e1a_yng_se * np.sqrt(vand_e1a_yng_n)
vand_e1a_old_sd = vand_e1a_old_se * np.sqrt(vand_e1a_old_n)

vand_e1a_SMD = SMD(vand_e1a_old_m, vand_e1a_yng_m,
                   vand_e1a_old_sd,vand_e1a_yng_sd, 
                   vand_e1a_old_n, vand_e1a_yng_n)

vand_e1a_SE_SMD = SE_SMD(vand_e1a_old_n,vand_e1a_yng_n,vand_e1a_SMD)

vand_e1a_CI_low,vand_e1a_CI_high = get_95_CI(vand_e1a_SMD,vand_e1a_SE_SMD)

print(vand_e1a_SMD, vand_e1a_CI_low, vand_e1a_CI_high, vand_e1a_SE_SMD)
# Out:
# 0.2418852584910332 -0.3803023736643604 0.8640728906464268 0.3174426694670376

# %%
### Vandevoorde et al. 2019 ###
# Experiment E1b
vand_e1b_yng_n = 31
vand_e1b_old_n = 31

# extracted from fig 2d (using webplotdigitizer)
vand_e1b_yng_m = 10.8668
vand_e1b_old_m = 12.4148

vand_e1b_yng_se = 11.8575 - vand_e1b_yng_m
vand_e1b_old_se = 14.1795 - vand_e1b_old_m

vand_e1b_yng_sd = vand_e1b_yng_se * np.sqrt(vand_e1b_yng_n)
vand_e1b_old_sd = vand_e1b_old_se * np.sqrt(vand_e1b_old_n)

vand_e1b_SMD = SMD(vand_e1b_old_m, vand_e1b_yng_m,
                   vand_e1b_old_sd,vand_e1b_yng_sd, 
                   vand_e1b_old_n, vand_e1b_yng_n)

vand_e1b_SE_SMD = SE_SMD(vand_e1b_old_n,vand_e1b_yng_n,vand_e1b_SMD)

vand_e1b_CI_low,vand_e1b_CI_high = get_95_CI(vand_e1b_SMD,vand_e1b_SE_SMD)

print(vand_e1b_SMD, vand_e1b_CI_low, vand_e1b_CI_high, vand_e1b_SE_SMD)
# Out:
# 0.19428691499657516 -0.30476576915601483 0.6933395991491652 0.25461871640438266

# %%
SMD_heuer = 0.2714

SE_SMD_heuer = SE_SMD(38,38,SMD_heuer)

low_CI,high_CI = get_95_CI(SMD_heuer,SE_SMD_heuer)

low_CI, high_CI
# Out:
# (-0.18037582431459237, 0.7231758243145923)

# %%
### bock et al. 2005 ###
bock_N_young = 12
bock_N_old = 12

# extracted from fig 1 (using webplotdigitizer)
bock_mean_young = 25.65
bock_mean_old = 21.88

bock_sd_young = 5.882
bock_sd_old = 8

bock_SMD = SMD( bock_mean_old, bock_mean_young,  bock_sd_old, bock_sd_young,bock_N_old, bock_N_young)
bock_SE_SMD = SE_SMD(bock_N_old,bock_N_young,bock_SMD)
bock_95_low, bock_95_high = get_95_CI(bock_SMD, bock_SE_SMD)

print(bock_SMD, bock_SE_SMD, bock_95_low, bock_95_high)
# Out:
# -0.5369359251719529 0.4161957996673723 -1.3526796925200024 0.2788078421760968

# %%
bindra_N_young = 20
bindra_N_old = 19

### Fig 3A&B (using webplotdigitizer)
### Data extracted from text
bindra_mean_young = 22.34
bindra_mean_old = 24.58

bindra_yng_sme = 2.67
bindra_old_sme = 3.06

bindra_sd_old = bindra_old_sme * np.sqrt(bindra_N_young)
bindra_sd_young = bindra_yng_sme * np.sqrt(bindra_N_old)

bindra_SMD =  SMD(bindra_mean_old, bindra_mean_young,  bindra_sd_old,
                       bindra_sd_young, bindra_N_old, bindra_N_young)

bindra_SE_SMD = SE_SMD(bindra_N_old,bindra_N_young,bindra_SMD)
bindra_95_low, bindra_95_high = get_95_CI(bindra_SMD, bindra_SE_SMD)

print(bindra_SMD, bindra_SE_SMD, bindra_95_low, bindra_95_high)
# Out:
# 0.1767232997048939 0.3210196585452119 -0.45247523104372145 0.8059218304535092

# %%
### cressman 2006 ###
cressman_young_N = 10
cressman_old_N = 9

cressman_young_m = 18.51851852
cressman_old_m = 17.4691358

cressman_young_sd = SE_to_SD(21.54320988 - cressman_young_m, cressman_young_N)
cressman_old_sd = SE_to_SD(20.43209877 -cressman_old_m, cressman_old_N)

cressman_SMD =  SMD(cressman_old_m, cressman_young_m,  cressman_old_sd, 
                 cressman_young_sd, cressman_old_N, cressman_young_N)
cressman_SE_SMD = SE_SMD(cressman_old_N,cressman_young_N,cressman_SMD)
cressman_95_low, cressman_95_high = get_95_CI(cressman_SMD, cressman_SE_SMD)

print(cressman_SMD, cressman_SE_SMD, cressman_95_low, cressman_95_high)
# Out:
# -0.11341074617781627 0.4598797724957862 -1.0147751002695573 0.7879536079139247

# %%
### fernandez-ruiz 2000 ###
fr_young_n = 20
fr_old_n = 20

fr_young_m = 26
fr_old_m = 47

fr_young_se = 2.2
fr_old_se = 5.4

fr_young_sd = fr_young_se * np.sqrt(fr_young_n)
fr_old_sd = fr_old_se * np.sqrt(fr_old_n)

fr_SMD = SMD(fr_old_m, fr_young_m,
             fr_old_sd, fr_young_sd, 
             fr_old_n, fr_young_n)
fr_SE_SMD = SE_SMD(fr_old_n, fr_young_n,fr_SMD)
fr_95_low, fr_95_high = get_95_CI(fr_SMD,fr_SE_SMD)

print(fr_SMD, fr_SE_SMD, fr_95_low, fr_95_high)
# Out:
# 1.1388849035479447 0.34214991373298964 0.468271072631285 1.8094987344646043

# %%
### cornelis et al ###
corn_old_n = 30
corn_yng_n = 30

# extracted from fig 2 (using webplotdigitizer)
corn_old_m = 11.76470588
corn_yng_m = 12.84313725

corn_old_se = 0.7843137255
corn_yng_se = 0.8823529412

corn_old_sd = corn_old_se * np.sqrt(corn_old_n)
corn_yng_sd = corn_yng_se * np.sqrt(corn_yng_n)

corn_SMD = SMD(corn_old_m, corn_yng_m,
              corn_old_sd, corn_yng_sd,
              corn_old_n, corn_yng_n)
corn_SE_SMD = SE_SMD(corn_old_n, corn_yng_n, corn_SMD)
corn_95_low, corn_95_high = get_95_CI(corn_SMD, corn_SE_SMD)

print(corn_SMD, corn_SE_SMD,corn_95_low,corn_95_high)
# Out:
# -0.23586475710200153 0.25912594323357646 -0.7437516058398114 0.27202209163580837

# %%
## Nemanich & Earhart, 2015
nemanich_old_n = 18
nemanich_yng_n = 15

# extracted from fig 2b (using webplotdigitizer)
nemanich_old_m = 10.360
nemanich_yng_m = 8.393
 
nemanich_old_sme = nemanich_old_m - 9.717
nemanich_yng_sme = nemanich_yng_m - 7.802

nemanich_old_sd = nemanich_old_sme * np.sqrt(nemanich_old_n)
nemanich_yng_sd = nemanich_yng_sme * np.sqrt(nemanich_yng_n)

nemanich_SMD = SMD(nemanich_old_m, nemanich_yng_m,
                   nemanich_old_sd, nemanich_yng_sd,
                   nemanich_old_n, nemanich_yng_n)

nemanich_SE_SMD = SE_SMD(nemanich_old_n, nemanich_yng_n, nemanich_SMD)
nemanich_95_low, nemanich_95_high = get_95_CI(nemanich_SMD, nemanich_SE_SMD)

print(nemanich_SMD, nemanich_95_low, nemanich_95_high, nemanich_SE_SMD)
# Out:
# 0.7746713247669147 0.06283368203296857 1.486508967500861 0.36318247078262555

# %%
## Panouilleres et al. 2015
pano_old_n = 13
pano_yng_n = 14

# extracted from fig 3 (using webplotdigitizer)
pano_old_m = 5
pano_yng_m = 2.593
 
pano_old_sme = 0.463
pano_yng_sme = 0.463

pano_old_sd = pano_old_sme * np.sqrt(pano_old_n)
pano_yng_sd = pano_yng_sme * np.sqrt(pano_yng_n)

pano_SMD = SMD(pano_old_m, pano_yng_m,
               pano_old_sd,pano_yng_sd,
               pano_old_n, pano_yng_n)

pano_SE_SMD = SE_SMD(pano_old_n,pano_yng_n, pano_SMD)
pano_95_low, pano_95_high = get_95_CI(pano_SMD, pano_SE_SMD)

print(pano_SMD, pano_SE_SMD, pano_95_low, pano_95_high)
# Out:
# 1.4138611250340756 0.4339720198000106 0.5632759662260548 2.2644462838420965

# %%
## Hardwick & Celnik 2014
hardwick_old_n = 11
hardwick_yng_n = 11 

# extracted from fig 1c (using webplotdigitizer)
hardwick_old_m = 13.72693727 
hardwick_yng_m = 17.04797048

hardwick_old_sem = 2.21402214
hardwick_old_sd = hardwick_old_m * np.sqrt(hardwick_old_n)

hardwick_yng_sem = 0.7749077491
hardwick_yng_sd = hardwick_yng_m * np.sqrt(hardwick_yng_n)

hardwick_SMD = SMD(hardwick_old_m, hardwick_yng_m,
               hardwick_old_sd, hardwick_yng_sd,
               hardwick_old_n, hardwick_yng_n)

hardwick_SE_SMD = SE_SMD(hardwick_old_n,hardwick_yng_n, hardwick_SMD)
hardwick_95_low, hardwick_95_high = get_95_CI(hardwick_SMD, hardwick_SE_SMD)

print(hardwick_SMD, hardwick_SE_SMD, hardwick_95_low, hardwick_95_high)
# Out:
# -0.06469876114663743 0.4265241260005459 -0.9006860481077074 0.7712885258144325

# %%
### Reuter et al. 2020 ###
reuter_old_n = 25
reuter_yng_n = 24

# Indicated in text 
reuter_old_m = 59.4
reuter_yng_m = 54.2

reuter_old_sem = 15.0
reuter_yng_sem = 14.7 

reuter_old_sd = reuter_old_sem * np.sqrt(reuter_old_n)
reuter_yng_sd = reuter_yng_sem * np.sqrt(reuter_yng_n)

reuter_SMD = SMD(reuter_old_m, reuter_yng_m,
               reuter_old_sd, reuter_yng_sd,
               reuter_old_n, reuter_yng_n)

reuter_SE_SMD = SE_SMD(reuter_old_n,reuter_yng_n, reuter_SMD)
reuter_95_low, reuter_95_high = get_95_CI(reuter_SMD, reuter_SE_SMD)

print(reuter_SMD, reuter_SE_SMD, reuter_95_low, reuter_95_high)
# Out:
# 0.07069598283851718 0.28586681522963403 -0.48960297501156547 0.6309949406885998

# %%
### Uresti-Cabrera et al. 2015 ###
uresti_old_n = 41
uresti_yng_n = 41

# extracted from fig 2 (using webplotdigitizer)
uresti_old_m = 20.85
uresti_yng_m = 14.47

uresti_old_sem = 22.55 - uresti_old_m
uresti_yng_sem = 16.17 - uresti_yng_m

uresti_old_sd = uresti_old_sem * np.sqrt(uresti_old_n)
uresti_yng_sd = uresti_yng_sem * np.sqrt(uresti_yng_n)

uresti_SMD = SMD(uresti_old_m, uresti_yng_m,
               uresti_old_sd, uresti_yng_sd,
               uresti_old_n, uresti_yng_n)

uresti_SE_SMD = SE_SMD(uresti_old_n, uresti_yng_n, uresti_SMD)
uresti_95_low, uresti_95_high = get_95_CI(uresti_SMD, uresti_SE_SMD)

print(uresti_SMD, uresti_SE_SMD, uresti_95_low, uresti_95_high)
# Out:
# 0.5861109416760628 0.22567127759105843 0.14379523759758828 1.0284266457545375

# %%
### Simon & Bock 2016 ###
simon_old_n = 25
simon_yng_n = 25

# extracted from fig 1 (using webplotdigitizer)
simon_old_m = 17.14
simon_yng_m = 22.86

simon_old_sd = simon_old_m - 5.079
simon_yng_sd = 32.7 - simon_yng_m 

print(simon_old_sd,simon_yng_sd)

simon_SMD = SMD(simon_old_m, simon_yng_m,
               simon_old_sd, simon_yng_sd,
               simon_old_n, simon_yng_n)

simon_SE_SMD = SE_SMD(simon_old_n, simon_yng_n, simon_SMD)
simon_95_low, simon_95_high = get_95_CI(simon_SMD, simon_SE_SMD)

print(simon_SMD, simon_SE_SMD, simon_95_low, simon_95_high)
# Out:
# 12.061 9.840000000000003
# -0.5196851479237704 0.2877729257623055 -1.0837200824178892 0.04434978657034838

# %%
## Simon & Bock 2017
simon_2017_old_n = 20
simon_2017_yng_n = 20

# extracted from fig 1 (using webplotdigitizer)
simon_2017_old_m = 26.407
simon_2017_yng_m = 27.075

simon_2017_old_sd = simon_2017_old_m - 18.830
simon_2017_yng_sd=  34.206 - simon_2017_yng_m

simon_2017_SMD = SMD(simon_2017_old_m, simon_2017_yng_m,
               simon_2017_old_sd, simon_2017_yng_sd,
               simon_2017_old_n, simon_2017_yng_n)

simon_2017_SMD = -0.0849 #Keeping sheer's value because almost the same as what I got 

simon_2017_SE_SMD = SE_SMD(simon_2017_old_n, simon_2017_yng_n, simon_2017_SMD)
simon_2017_95_low, simon_2017_95_high = get_95_CI(simon_2017_SMD, simon_2017_SE_SMD)

print(simon_2017_SMD, simon_2017_95_low, simon_2017_95_high, simon_2017_SE_SMD)
# Out:
# -0.09079318616333354 -0.7109356555290263 0.5293492832023592 0.31639921906412893

# %%
## Hegele & Heuer 2013 
# Control Condition
hegele_2013_old_n = 19
hegele_2013_yng_n = 19

# extracted from fig 2b (using webplotdigitizer)
hegele_2013_old_m = 13.56
hegele_2013_yng_m = 10.35

hegele_2013_old_sem =  15.63 - hegele_2013_old_m
hegele_2013_yng_sem =  12.41 - hegele_2013_yng_m

hegele_2013_old_sd = hegele_2013_old_sem * np.sqrt(hegele_2013_old_n)
hegele_2013_yng_sd = hegele_2013_yng_sem * np.sqrt(hegele_2013_yng_n)

hegele_2013_SMD = SMD(hegele_2013_old_m, hegele_2013_yng_m,
                   hegele_2013_old_sd, hegele_2013_yng_sd,
                   hegele_2013_old_n, hegele_2013_yng_n)

hegele_2013_SE_SMD = SE_SMD(hegele_2013_old_n,hegele_2013_yng_n, hegele_2013_SMD)
hegele_2013_95_low, hegele_2013_95_high = get_95_CI(hegele_2013_SMD, hegele_2013_SE_SMD)

print(hegele_2013_SMD, hegele_2013_95_low, hegele_2013_95_high, hegele_2013_SE_SMD)
# Out:
# 0.3566209912856948 -0.28460020967959854 0.9978421922509881 0.3271536739618844

# %%
## Hegele & Heuer 2013 
# Explicit pretraining condition
hegele_2013_old_n = 19
hegele_2013_yng_n = 19

# extracted from fig 2b (using webplotdigitizer)
hegele_2013_old_m = 12.056
hegele_2013_yng_m = 10.187

hegele_2013_old_sem =  14.019 - hegele_2013_old_m
hegele_2013_yng_sem =  12.243 - hegele_2013_yng_m

hegele_2013_old_sd = hegele_2013_old_sem * np.sqrt(hegele_2013_old_n)
hegele_2013_yng_sd = hegele_2013_yng_sem * np.sqrt(hegele_2013_yng_n)

hegele_2013_SMD = SMD(hegele_2013_old_m, hegele_2013_yng_m,
                   hegele_2013_old_sd, hegele_2013_yng_sd,
                   hegele_2013_old_n, hegele_2013_yng_n)

hegele_2013_SE_SMD = SE_SMD(hegele_2013_old_n,hegele_2013_yng_n, hegele_2013_SMD)
hegele_2013_95_low, hegele_2013_95_high = get_95_CI(hegele_2013_SMD, hegele_2013_SE_SMD)

print(hegele_2013_SMD, hegele_2013_95_low, hegele_2013_95_high, hegele_2013_SE_SMD)
# Out:
# 0.2133183653628203 -0.4244957746899506 0.8511325054155913 0.32541537757794436

# %%
## Weightman et al. 2020 
# Sham forcefield condition
weightman_old_n = 15
weightman_yng_n = 12

# extracted from fig 2 (using webplotdigitizer)
weightman_old_m = 49.81
weightman_yng_m = 46.15

weightman_old_sem = weightman_old_m - 47.55
weightman_yng_sem = weightman_yng_m - 44.42

weightman_old_sd = weightman_old_sem * np.sqrt(weightman_old_n)
weightman_yng_sd = weightman_yng_sem * np.sqrt(weightman_yng_n)

weightman_SMD = SMD(weightman_old_m, weightman_yng_m,
                    weightman_old_sd, weightman_yng_sd,
                    weightman_old_n, weightman_yng_n)

weightman_SE_SMD = SE_SMD(weightman_old_n, weightman_yng_n, weightman_SMD)
weightman_95_low, weightman_95_high = get_95_CI(weightman_SMD, weightman_SE_SMD)

print(weightman_SMD, weightman_95_low, weightman_95_high, weightman_SE_SMD)
# Out:
# 0.4776816279577339 -0.2928840769669477 1.2482473328824155 0.3931457678187151

# %%
## Weightman et al. 2020 
# Sham joystick vmr condition
weightman_2_old_n = 15
weightman_2_yng_n = 12

# extracted from fig 2 (using webplotdigitizer)
weightman_2_old_m = 48.68
weightman_2_yng_m = 50.77

weightman_2_old_sem =  51.92 - weightman_2_old_m
weightman_2_yng_sem =  50.38 - weightman_2_yng_m 

weightman_2_old_sd = weightman_2_old_sem * np.sqrt(weightman_2_old_n)
weightman_2_yng_sd = weightman_2_yng_sem * np.sqrt(weightman_2_yng_n)

weightman_2_SMD =  SMD(weightman_2_old_m, weightman_2_yng_m,
                    weightman_2_old_sd, weightman_2_yng_sd,
                    weightman_2_old_n, weightman_2_yng_n)

weightman_2_SE_SMD = SE_SMD(weightman_2_old_n, weightman_2_yng_n, weightman_2_SMD)
weightman_2_95_low, weightman_2_95_high = get_95_CI(weightman_2_SMD, weightman_2_SE_SMD)

print(weightman_2_SMD, weightman_2_95_low, weightman_2_95_high, weightman_2_SE_SMD)
# Out:
# -0.22156080786244492 -0.9831457478182749 0.5400241320933851 0.38856374487542344

# %%
## Uresti-Cabrera et al. 2015
uresti_2015_old_n = 22
uresti_2015_yng_n = 25

# extracted from fig 1 (using webplotdigitizer)
uresti_2015_old_m = 18.79
uresti_2015_yng_m = 13.92

uresti_2015_old_sem = 21.87 - uresti_2015_old_m
uresti_2015_yng_sem = 16.81 - uresti_2015_yng_m

uresti_2015_old_sd = uresti_2015_old_sem * np.sqrt(uresti_2015_old_n)
uresti_2015_yng_sd = uresti_2015_yng_sem * np.sqrt(uresti_2015_yng_n)

uresti_2015_SMD = SMD(uresti_2015_old_m, uresti_2015_yng_m,
                       uresti_2015_old_sd, uresti_2015_yng_sd,
                       uresti_2015_old_n, uresti_2015_yng_n)

uresti_2015_SE_SMD = SE_SMD(uresti_2015_old_n, uresti_2015_yng_n, uresti_2015_SMD)
uresti_2015_95_low, uresti_2015_95_high = get_95_CI(uresti_2015_SMD, uresti_2015_SE_SMD)

print(uresti_2015_SMD, uresti_2015_95_low, uresti_2015_95_high, uresti_2015_SE_SMD)
# Out:
# 0.3370625301344496 -0.24011301560996218 0.9142380758788613 0.29447731925735293

# %%
### vandevoorde E1 2020 ###
vandevoorde_old_n = 40
vandevoorde_yng_n = 41

vandevoorde_old_m = 13.406
vandevoorde_yng_m = 11.424

vandevoorde_old_sem = 14.334 - vandevoorde_old_m
vandevoorde_yng_sem = 12.268 - vandevoorde_yng_m

vandevoorde_old_sd = vandevoorde_old_sem * np.sqrt(vandevoorde_old_n)
vandevoorde_yng_sd = vandevoorde_yng_sem * np.sqrt(vandevoorde_yng_n)

vandevoorde_SMD = SMD(vandevoorde_old_m, vandevoorde_yng_m,
                      vandevoorde_old_sd, vandevoorde_yng_sd,
                      vandevoorde_old_n, vandevoorde_yng_n)

#vandevoorde_SMD = 0.3913 # This is probably correct since I got similar values extracting 
                          # data from fig so will keep same values spreadsheet

vandevoorde_SE_SMD = SE_SMD(vandevoorde_old_n,vandevoorde_yng_n,vandevoorde_SMD)

vandevoorde_95_low, vandevoorde_95_high = get_95_CI(vandevoorde_SMD, vandevoorde_SE_SMD)

print(vandevoorde_SMD, vandevoorde_95_low, vandevoorde_95_high, vandevoorde_SE_SMD)
# Out:
# 0.3515079955271417 -0.08751562304594218 0.7905316141002255 0.22399164212912442

# %%
### Experiment 2
vandevoorde_E2_old_n = 32
vandevoorde_E2_yng_n = 30

# extracted from fig 3b (using webplotdigitizer)
vandevoorde_E2_old_m = 16.683
vandevoorde_E2_yng_m = 15.467

vandevoorde_E2_old_sem = 17.607 - vandevoorde_E2_old_m
vandevoorde_E2_yng_sem = 16.537 - vandevoorde_E2_yng_m

vandevoorde_E2_old_sd = vandevoorde_E2_old_sem * np.sqrt(vandevoorde_E2_old_n)
vandevoorde_E2_yng_sd = vandevoorde_E2_yng_sem * np.sqrt(vandevoorde_E2_yng_n)

vandevoorde_E2_SMD = SMD(vandevoorde_E2_old_m, vandevoorde_E2_yng_m,
                         vandevoorde_E2_old_sd, vandevoorde_E2_yng_sd,
                         vandevoorde_E2_old_n, vandevoorde_E2_yng_n)

# vandevoorde_E2_SMD = 0.3215 #A bit different from what I extracted from the figure

vandevoorde_E2_SE_SMD = SE_SMD(vandevoorde_E2_old_n, vandevoorde_E2_yng_n,vandevoorde_E2_SMD)

vandevoorde_E2_95_low, vandevoorde_E2_95_high = get_95_CI(vandevoorde_E2_SMD, vandevoorde_E2_SE_SMD)

print(vandevoorde_E2_SMD, vandevoorde_E2_95_low, vandevoorde_E2_95_high, vandevoorde_E2_SE_SMD)
# Out:
# 0.21940448276633845 -0.28023979233700846 0.7190487578696854 0.25492054852211576

# %%
## Huang & Ahmed 2013
huang_old_n = 11
huang_yng_n = 15

# data in text (adaptation index) 
huang_old_m = 51.36
huang_yng_m = 84.05

huang_old_sem = 7.91
huang_yng_sem = 5.48

huang_old_sd = huang_old_sem * np.sqrt(huang_old_n)
huang_yng_sd = huang_yng_sem * np.sqrt(huang_yng_n)

print(huang_old_sd,huang_yng_sd)

#keep the sign since this is magnitiude of adaptation and not error
huang_SMD = SMD(huang_old_m, huang_yng_m,
                huang_old_sd, huang_yng_sd,
                huang_old_n, huang_yng_n)

huang_SE_SMD = SE_SMD(huang_old_n, huang_yng_n, huang_SMD)
huang_95_low, huang_95_high = get_95_CI(huang_SMD, huang_SE_SMD)

print(huang_SMD, huang_95_low, huang_95_high, huang_SE_SMD)
# Out:
# 26.234502091711214 21.22394873721665
# -1.394494049307027 -2.26683397332883 -0.5221541252852238 0.4450713898070425

# %%
### Kitchen & Miall 2010 ###
#vision +
kitchen_old_n = 17
kitchen_yng_n = 17

# extracted from fig 3d (using webplotdigitizer)
kitchen_old_m = 0.2353
kitchen_yng_m = 0.1118

kitchen_old_sem = 0.2647 - kitchen_old_m 
kitchen_yng_sem = 0.1352 - kitchen_yng_m

kitchen_old_sd = kitchen_old_sem * np.sqrt(kitchen_old_n)
kitchen_yng_sd = kitchen_yng_sem * np.sqrt(kitchen_yng_n)

kitchen_SMD = SMD(kitchen_old_m, kitchen_yng_m,
                  kitchen_old_sd, kitchen_yng_sd,
                  kitchen_old_n, kitchen_yng_n)

kitchen_SE_SMD = SE_SMD(kitchen_old_n, kitchen_yng_n, kitchen_SMD)
kitchen_95_low, kitchen_95_high = get_95_CI(kitchen_SMD, kitchen_SE_SMD)

print(kitchen_SMD, kitchen_95_low, kitchen_95_high, kitchen_SE_SMD)
# Out:
# 1.127333595888692 0.40053405310709345 1.8541331386702908 0.3708160932559177

# %%
### Kitchen & Miall 2010 ###
#vision -
kitch_old_n = 17
kitch_yng_n = 18

# extracted from fig 3d (using webplotdigitizer)
kitch_old_m = 0.1588
kitch_yng_m = 0.1176

kitch_old_sem = 0.2177 - kitch_old_m 
kitch_yng_sem = 0.1647 - kitch_yng_m

kitch_old_sd = kitch_old_sem * np.sqrt(kitch_old_n)
kitch_yng_sd = kitch_yng_sem * np.sqrt(kitch_yng_n)

kitch_SMD = SMD(kitch_old_m, kitch_yng_m,
                kitch_old_sd, kitch_yng_sd,
                kitch_old_n, kitch_yng_n)

kitch_SE_SMD = SE_SMD(kitch_old_n, kitch_yng_n, kitch_SMD)
kitch_95_low, kitch_95_high = get_95_CI(kitch_SMD, kitch_SE_SMD)

print(kitch_SMD, kitch_95_low, kitch_95_high, kitch_SE_SMD)
# Out:
# 0.1858092698539098 -0.4785763576145352 0.8501948973223548 0.33897225891247196

# %%
### Hegele & Heuer 2010 ###
hegele_2010_old_n = 18 #5 people excluded but doesn't indicate from what group
hegele_2010_yng_n = 18

# extracted from fig 2 (using webplotdigitizer)
hegele_2010_old_m = 16.36
hegele_2010_yng_m = 5.455

hegele_2010_old_sem =  19.09 - hegele_2010_old_m
hegele_2010_yng_sem =  8.182 - hegele_2010_yng_m 

hegele_2010_old_sd = hegele_2010_old_sem * np.sqrt(hegele_2010_old_n)
hegele_2010_yng_sd = hegele_2010_yng_sem * np.sqrt(hegele_2010_yng_n)

hegele_2010_SMD = SMD(hegele_2010_old_m, hegele_2010_yng_m,
                       hegele_2010_old_sd, hegele_2010_yng_sd,
                       hegele_2010_old_n, hegele_2010_yng_n)

hegele_2010_SE_SMD = SE_SMD(hegele_2010_old_n,hegele_2010_yng_n, hegele_2010_SMD)
hegele_2010_95_low, hegele_2010_95_high = get_95_CI(hegele_2010_SMD, hegele_2010_SE_SMD)

print(hegele_2010_SMD, hegele_2010_95_low, hegele_2010_95_high, hegele_2010_SE_SMD)
# Out:
# 0.9420314316290819 0.2513950322589972 1.6326678309991665 0.35236550988269627

# %%
## Langan & Seidler 2011
## 30 degrees
## Only concern is that it's not fully clear whether this is actually an aftereffect measure and if
## Participants were given feedback 
langan_old_n = 9
langan_yng_n = 9

# extracted from fig 1 (using webplotdigitizer)
langan_old_m = 11.71
langan_yng_m = 6.176

langan_old_se = 15.71 - langan_old_m
langan_yng_se = 8.235 - langan_yng_m

langan_old_sd = langan_old_se * np.sqrt(langan_old_n)
langan_yng_sd = langan_yng_se * np.sqrt(langan_yng_n)


langan_SMD = SMD(langan_old_m,langan_yng_m,
                langan_old_sd,langan_yng_sd,
                langan_old_n,langan_yng_n)

langan_SE_SMD = SE_SMD(langan_old_n, langan_yng_n, langan_SMD)
langan_95_low,langan_95_high = get_95_CI(langan_SMD, langan_SE_SMD)

print(langan_SMD, langan_95_low, langan_95_high, langan_SE_SMD)
# Out:
# 0.5798734331728062 -0.3656719572600212 1.5254188236056336 0.48242111756776906

# %%
## Langan & Seidler 2011
## 45 degrees
## Checked but not corrected since data may be excluded. 
langan_45_old_n = 9
langan_45_yng_n = 9

# extracted from fig 2 (using webplotdigitizer)
langan_45_old_m = 9.355
langan_45_yng_m = 2.667

langan_45_old_se = 11.61 - langan_45_old_m
langan_45_yng_se = 5 - langan_45_yng_m

langan_45_old_sd = langan_45_old_se * np.sqrt(langan_45_old_n)
langan_45_yng_sd = langan_45_yng_se * np.sqrt(langan_45_yng_n)

#langan_SMD = -1.123
langan_45_SMD = SMD(langan_45_old_m,langan_45_yng_m,
                langan_45_old_sd,langan_45_yng_sd,
                langan_45_old_n,langan_45_yng_n)

langan_45_SE_SMD = SE_SMD(langan_45_old_n, langan_45_yng_n, langan_45_SMD)
langan_45_95_low,langan_45_95_high = get_95_CI(langan_45_SMD, langan_45_SE_SMD)

print(langan_45_SMD, langan_45_95_low, langan_45_95_high, langan_45_SE_SMD)
# Out:
# 0.9716701096099939 -0.011708369032956578 1.9550485882529443 0.5017237135933421

# %%
## Heuer et al 2008
heuer_2008_old_n = 20
heuer_2008_yng_n = 20

# extracted from fig 2b (using webplotdigitizer)
heuer_2008_old_m = 13.223
heuer_2008_yng_m = 10.155

heuer_2008_old_sem = 2.406
heuer_2008_yng_sem = 2.431 

heuer_2008_old_sd = heuer_2008_old_sem * np.sqrt(heuer_2008_old_n)
heuer_2008_yng_sd = heuer_2008_yng_sem * np.sqrt(heuer_2008_yng_n)

heuer_2008_SMD = SMD(heuer_2008_old_m, heuer_2008_yng_m,
                    heuer_2008_old_sd, heuer_2008_yng_sd,
                    heuer_2008_old_n, heuer_2008_yng_n)

heuer_2008_SE_SMD = SE_SMD(heuer_2008_old_n, heuer_2008_yng_n, heuer_2008_SMD)
heuer_2008_95_low, heuer_2008_95_high = get_95_CI(heuer_2008_SMD, heuer_2008_SE_SMD)

print(heuer_2008_SMD, heuer_2008_95_low, heuer_2008_95_high, heuer_2008_SE_SMD)
# Out:
# 0.2836537079469043 -0.3394249486050493 0.9067323644988579 0.31789727375099675

# %%
### Hermans et al. unpublished ###
Hermans_unpub_old_n = 20
Hermans_unpub_yng_n = 28

# mean adaptation across each group
Hermans_unpub_old_m = 10.91 
Hermans_unpub_yng_m = 11.96 

# sd across each group
Hermans_unpub_old_sd = 3.09
Hermans_unpub_yng_sd = 3.70

Hermans_unpub_SMD = SMD(Hermans_unpub_old_m, Hermans_unpub_yng_m,
                    Hermans_unpub_old_sd, Hermans_unpub_yng_sd,
                    Hermans_unpub_old_n, Hermans_unpub_yng_n)

# Hermans_unpub_SMD = -0.308

Hermans_unpub_SE_SMD = SE_SMD(Hermans_unpub_old_n, Hermans_unpub_yng_n, Hermans_unpub_SMD)
Hermans_unpub_95_low, Hermans_unpub_95_high = get_95_CI(Hermans_unpub_SMD, Hermans_unpub_SE_SMD)

print(Hermans_unpub_SMD, Hermans_unpub_95_low, Hermans_unpub_95_high, Hermans_unpub_SE_SMD)
# Out:
# -0.30337173500454995 -0.8805398533420034 0.27379638333290346 0.29447352976400687

# %%
### Hermans et al. unpublished ###
Hermans_unpub_old_n = 20
Hermans_unpub_yng_n = 28

# data from authors 
Hermans_unpub_old_m = 3.39  
Hermans_unpub_yng_m = 3.53

Hermans_unpub_old_sd = 1.01
Hermans_unpub_yng_sd = 1.1

Hermans_unpub_SMD = SMD(Hermans_unpub_old_m, Hermans_unpub_yng_m,
                    Hermans_unpub_old_sd, Hermans_unpub_yng_sd,
                    Hermans_unpub_old_n, Hermans_unpub_yng_n)

Hermans_unpub_SE_SMD = SE_SMD(Hermans_unpub_old_n, Hermans_unpub_yng_n, Hermans_unpub_SMD)
Hermans_unpub_95_low, Hermans_unpub_95_high = get_95_CI(Hermans_unpub_SMD, Hermans_unpub_SE_SMD)

# Hermans_unpub_SMD = 0.127

print(Hermans_unpub_SMD, Hermans_unpub_95_low, Hermans_unpub_95_high, Hermans_unpub_SE_SMD)
# Out:
# -0.13160993000049845 -0.7060690425273138 0.4428491825263169 0.29309138394225276

# %%
### Pacheco et al. unpublished ###
Pacheco_unpub_old_n = 30
Pacheco_unpub_yng_n = 32

# data from authors
Pacheco_unpub_old_m = 13.79 
Pacheco_unpub_yng_m = 15.06 

Pacheco_unpub_old_sd = 7.22
Pacheco_unpub_yng_sd = 6.51

Pacheco_unpub_SMD = SMD(Pacheco_unpub_old_m, Pacheco_unpub_yng_m,
                    Pacheco_unpub_old_sd, Pacheco_unpub_yng_sd,
                    Pacheco_unpub_old_n, Pacheco_unpub_yng_n)

Pacheco_unpub_SE_SMD = SE_SMD(Pacheco_unpub_old_n, Pacheco_unpub_yng_n, Pacheco_unpub_SMD)
Pacheco_unpub_95_low, Pacheco_unpub_95_high = get_95_CI(Pacheco_unpub_SMD, Pacheco_unpub_SE_SMD)

print(Pacheco_unpub_SMD, Pacheco_unpub_95_low, Pacheco_unpub_95_high, Pacheco_unpub_SE_SMD)
# Out:
# -0.18506793342916475 -0.6842670865547948 0.3141312196964653 0.25469344547226025

# %%
### VanDePlas et al. unpublished ###
VanDePlas_unpub_old_n = 35
VanDePlas_unpub_yng_n = 37

# data from authors
VanDePlas_unpub_old_m = 19.1569 
VanDePlas_unpub_yng_m = 20.1286 

VanDePlas_unpub_old_sd = 8.8121
VanDePlas_unpub_yng_sd = 7.6568

VanDePlas_unpub_SMD = SMD(VanDePlas_unpub_old_m, VanDePlas_unpub_yng_m,
                    VanDePlas_unpub_old_sd, VanDePlas_unpub_yng_sd,
                    VanDePlas_unpub_old_n, VanDePlas_unpub_yng_n)

VanDePlas_unpub_SE_SMD = SE_SMD(VanDePlas_unpub_old_n, VanDePlas_unpub_yng_n, VanDePlas_unpub_SMD)
VanDePlas_unpub_95_low, VanDePlas_unpub_95_high = get_95_CI(VanDePlas_unpub_SMD, VanDePlas_unpub_SE_SMD)

print(VanDePlas_unpub_SMD, VanDePlas_unpub_95_low, VanDePlas_unpub_95_high, VanDePlas_unpub_SE_SMD)
# Out:
# -0.11795043657621072 -0.5805180323820907 0.34461715922966923 0.23600387541116324

# %%
### Bansal et al. 2022 ###
## TOD0: should we include abrupt condition. No difference in late adaptation across conditions
## Graph uses confidence interval. Correct for this
Bansal_2022_old_n = 30
Bansal_2022_yng_n = 25

# extracted from fig 5 (using webplotdigitizer)
Bansal_2022_old_m = 9.555
Bansal_2022_yng_m = 10.786

Bansal_2022_old_sem = 3.707
Bansal_2022_yng_sem = 1.739

Bansal_2022_old_sd = Bansal_2022_old_sem * np.sqrt(Bansal_2022_old_n)
Bansal_2022_yng_sd = Bansal_2022_yng_sem * np.sqrt(Bansal_2022_old_n)

Bansal_2022_SMD = SMD(Bansal_2022_old_m, Bansal_2022_yng_m,
                    Bansal_2022_old_sd, Bansal_2022_yng_sd,
                    Bansal_2022_old_n, Bansal_2022_yng_n)

Bansal_2022_SE_SMD = SE_SMD(Bansal_2022_old_n, Bansal_2022_yng_n, Bansal_2022_SMD)
Bansal_2022_95_low, Bansal_2022_95_high = get_95_CI(Bansal_2022_SMD, Bansal_2022_SE_SMD)

print(Bansal_2022_SMD, Bansal_2022_95_low, Bansal_2022_95_high, Bansal_2022_SE_SMD)
# Out:
# -0.07538453387097736 -0.6063490219452591 0.4555799542033044 0.2709002490174907

# %%
### Khanafer et al 2022 ###
# TODO: Add augmented feedback condition (V + S)?
## Visual Feedback only condition (V)
Khanafer_2022_old_n = 9
Khanafer_2022_yng_n = 10

# mean adaptation across each group
# extracted from fig 4 (using webplotdigitizer)
Khanafer_2022_old_m = 14.803
Khanafer_2022_yng_m = 16.052

Khanafer_2022_old_sd = 4.604
Khanafer_2022_yng_sd = 4.963

Khanafer_2022_SMD = SMD(Khanafer_2022_old_m, Khanafer_2022_yng_m,
                    Khanafer_2022_old_sd, Khanafer_2022_yng_sd,
                    Khanafer_2022_old_n, Khanafer_2022_yng_n)

Khanafer_2022_SE_SMD = SE_SMD(Khanafer_2022_old_n, Khanafer_2022_yng_n, Khanafer_2022_SMD)
Khanafer_2022_95_low, Khanafer_2022_95_high = get_95_CI(Khanafer_2022_SMD, Khanafer_2022_SE_SMD)

print(Khanafer_2022_SMD, Khanafer_2022_95_low, Khanafer_2022_95_high, Khanafer_2022_SE_SMD)
# Out:
# -0.26034900519896587 -1.165148965589779 0.6444509551918475 0.4616326328524558

# %%
### Lazar-Kurz et al. 2022 ###
lz_young_n = 20
lz_old_n = 20

# extracted from fig 6 (using webplotdigitizer)
lz_young_m = 6.483
lz_old_m = 7.390

lz_young_CI = (6.237,6.724)
lz_old_CI = (7.119,7.667)

z_alpha_over_2 = stats.norm.ppf(0.975)
lz_young_SE = (lz_young_CI[1] - lz_young_m) / (2 * z_alpha_over_2)
lz_old_SE = (lz_old_CI[1] - lz_old_m) / (2 * z_alpha_over_2)

lz_young_sd = lz_young_SE * math.sqrt(lz_young_n)
lz_old_sd = lz_old_SE * math.sqrt(lz_old_n)

lz_SMD = SMD(lz_old_m, lz_young_m,
             lz_old_sd, lz_young_sd, 
             lz_old_n, lz_young_n)

lz_SE_SMD = SE_SMD(lz_old_n, lz_young_n,lz_SMD)
lz_95_low, lz_95_high = get_95_CI(lz_SMD,lz_SE_SMD)

print(lz_SMD, lz_95_low, lz_95_high, lz_SE_SMD)
# Out:
# 3.0621349007255794 2.1357839949415176 3.988485806509641 0.4726280131551336

# %%
### Cressman et al. 2010 ###
cressman_young_n = 10
cressman_old_n = 9

# extracted from fig 4 (using webplotdigitizer)
cressman_young_m = 18.399
cressman_old_m = 17.522

cressman_young_SE = 21.421 - cressman_young_m
cressman_old_SE = 20.398 - cressman_old_m

cressman_young_sd = cressman_young_SE * math.sqrt(cressman_young_n)
cressman_old_sd = cressman_old_SE * math.sqrt(cressman_old_n)

cressman_SMD = SMD(cressman_old_m, cressman_young_m,
                   cressman_old_sd, cressman_young_sd, 
                   cressman_old_n, cressman_young_n)


cressman_SE_SMD = SE_SMD(cressman_old_n, cressman_young_n,cressman_SMD)
cressman_95_low, cressman_95_high = get_95_CI(cressman_SMD,cressman_SE_SMD)

print(cressman_SMD, cressman_95_low, cressman_95_high, cressman_SE_SMD)
# Out:
# -0.09604355895994686 -0.9971798911495329 0.8050927732296391 0.4597634347906051
